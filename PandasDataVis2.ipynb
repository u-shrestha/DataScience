# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#plt.style.use('ggplot')
#plt.style.use('fivethirtyeight')
#plt.style.use('seaborn-pastel')

# %% [markdown]
# ### subplots and shared axis

# %%
weather = pd.read_csv('datasets/weather.csv')
weather.sample(10)
# Out:
#       MONTH  DAY  TIME  TEMP  PRESSURE
# 3676      6  154     5  13.1     10137
# 8410     12  351    11   6.4     10270
# 443       1   19    12   1.0     10159
# 5852      8  244    21  14.2     10206
# 4317      6  180    22  13.3     10101
# 7244     10  302    21  12.1     10346
# 6914     10  289     3   9.6     10043
# 5195      8  217    12  19.4     10094
# 7860     11  328    13   9.9     10185
# 8739     12  365     4  -1.0     10374

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MONTH     8784 non-null   int64
#  1   DAY       8784 non-null   int64
#  2   TIME      8784 non-null   int64
#  3   TEMP      8784 non-null   float64
#  4   PRESSURE  8784 non-null   int64
# dtypes: float64(1), int64(4)
# memory usage: 343.2 KB

# %% [markdown]
# **comparing progression of temp and pressure on two different dates**

# %%
#selection of first day of jan and jul
days = weather.loc[weather['DAY'].isin([1,105])].drop(columns= 'DAY')
days = days.pivot(columns= 'MONTH', index= 'TIME')
days.head()
# Out:
#       TEMP      PRESSURE
# MONTH    1    4        1      4
# TIME
# 1      6.8  4.3    10207  10113
# 2      5.8  5.9    10214  10114
# 3      5.7  5.7    10220  10114
# 4      6.0  6.0    10225  10113
# 5      4.5  6.5    10230  10110

# %%
ax = days.plot(subplots= True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# /home/usha/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /home/usha/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /home/usha/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# ...

# %%
ax = days.plot(subplots= True, layout= (2,2))
# Out:
# <img src="data:image/png;base64,..." width="640">
# /home/usha/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /home/usha/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /home/usha/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# ...

# %%
fig, ax = plt.subplots(2,2, sharey= 'row', sharex= 'col')
days['TEMP'].plot(subplots= True, ax= ax[0], legend= False)
days['PRESSURE'].plot(subplots= True, ax= ax[1], legend= False)
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /home/usha/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /home/usha/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /home/usha/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# ...

# %%
fig, ax = plt.subplots(2,2, sharey= 'row', sharex= 'col')
days['TEMP'].plot(subplots= True, ax= ax[0], legend= False)
days['PRESSURE'].plot(subplots= True, ax= ax[1], legend= False)
fig.tight_layout()

ax[0][0].set_ylabel('Temp')
ax[0][0].set_title('Jan')

ax[0][1].set_title('Apr')

ax[1][0].set_ylabel('Pressure')
ax[1][0].set_xlabel('Time')

ax[1][1].set_xlabel('Time')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /home/usha/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /home/usha/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /home/usha/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# ...

# %% [markdown]
# ### stacking with area and bar plots

# %%
sales = pd.read_csv('datasets/sales2.csv', parse_dates = ['Date'])
sales.head()
# Out:
#         Date  Amount Product
# 0 2017-01-20    5411       b
# 1 2017-02-22    5000       c
# 2 2017-03-01    7260       a
# 3 2017-03-14    2117       c
# 4 2017-04-15    7516       b

# %%
sales['Month'] = sales['Date'].dt.month
sales.head()
# Out:
#         Date  Amount Product  Month
# 0 2017-01-20    5411       b      1
# 1 2017-02-22    5000       c      2
# 2 2017-03-01    7260       a      3
# 3 2017-03-14    2117       c      3
# 4 2017-04-15    7516       b      4

# %%
grp = sales.groupby(['Month', 'Product'])['Amount'].sum()
grp
# Out:
# Month  Product
# 1      a           7260
#        b           9258
#        c           1740
# 2      a           6534
#        c           5000
# 3      a           7260
#        c           2117
# 4      a          11616
#        b          13221
#        c           5440
# 5      a           7119
#        c           2990
# 6      a          11071
#        c           7176
# 7      a           4200
#        b          15973
#        c           2901
# 8      a          10342
#        c           6662
# 9      c            660
# 10     a           2100
#        b          10711
#        c          14520
# 11     a           7260
#        c           3710
# 12     a          11616
#        b          14800
# Name: Amount, dtype: int64

# %%
grp = grp.unstack()
grp
# Out:
# Product        a        b        c
# Month
# 1         7260.0   9258.0   1740.0
# 2         6534.0      NaN   5000.0
# 3         7260.0      NaN   2117.0
# 4        11616.0  13221.0   5440.0
# 5         7119.0      NaN   2990.0
# 6        11071.0      NaN   7176.0
# 7         4200.0  15973.0   2901.0
# 8        10342.0      NaN   6662.0
# 9            NaN      NaN    660.0
# 10        2100.0  10711.0  14520.0
# 11        7260.0      NaN   3710.0
# 12       11616.0  14800.0      NaN

# %%
#total revenue per product
revenue = grp.fillna(0).cumsum()
revenue
# Out:
# Product        a        b        c
# Month
# 1         7260.0   9258.0   1740.0
# 2        13794.0   9258.0   6740.0
# 3        21054.0   9258.0   8857.0
# 4        32670.0  22479.0  14297.0
# 5        39789.0  22479.0  17287.0
# 6        50860.0  22479.0  24463.0
# 7        55060.0  38452.0  27364.0
# 8        65402.0  38452.0  34026.0
# 9        65402.0  38452.0  34686.0
# 10       67502.0  49163.0  49206.0
# 11       74762.0  49163.0  52916.0
# 12       86378.0  63963.0  52916.0

# %%
fig, ax = plt.subplots()
revenue.plot.area(title= 'Revenue 2017 (EUR)', ax= ax)
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()

total = sales.groupby('Month')['Amount'].sum().cumsum()
total.plot(ax = ax, style= 'r--', legend= True, label= 'All')

revenue.plot.area(title= 'Revenue 2017 (EUR)',
                  ax= ax, 
                  stacked= False,
                  grid= True)
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### top 10 countries to win olympics

# %%
ath = pd.read_csv('datasets/athletes.csv')
top = ath.groupby('nationality')[['gold', 'silver', 'bronze']]\
    .sum().sort_values('gold', ascending= False).head(10)
top
# Out:
#              gold  silver  bronze
# nationality
# USA           139      54      71
# GBR            64      55      26
# RUS            52      29      34
# GER            49      44      67
# CHN            46      30      37
# BRA            37       8       6
# AUS            23      34      25
# ARG            21       1       0
# FRA            20      54      21
# JPN            17      13      35

# %%
fig, ax = plt.subplots()
top.plot.bar(color= ['gold', 'silver', 'brown'], ax=ax, stacked= True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### styling a plot

# %%
styles= {'a': ':s', 'b': '--v', 'c': '-.o'}

with plt.style.context('seaborn-dark'):
    fig, ax = plt.subplots(figsize= (6,3))
    for columns in styles:
        grp[columns].dropna().plot(ax= ax, style= styles)
        
fig.suptitle('Sales 2017', fontweight= 'bold')
ax.set_title('monthly sales for products a, b and c',
             fontstyle= 'italic',
             fontsize= '10')
ax.set_ylabel('Sales (EUR)')
ax.grid(True)
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### scatter plots

# %%
f = ath[ath['sex'] == 'female']
m = ath[ath['sex'] == 'male']

tennis_f = f[f['sport'] == 'tennis']
tennis_m = m[m['sport'] == 'tennis']

gymnast_f = f[f['sport'] == 'gymnastics']
gymnast_m = m[m['sport'] == 'gymnastics']

# %%
gymnast_f.plot.scatter(x= 'weight', y= 'height')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
plots = [(tennis_f, 'red', 'Tennis, women'),
         (tennis_m, 'blue', 'Tennis, men'),
         (gymnast_f, 'orange', 'Gymnastics, women'),
         (gymnast_m, 'green', 'Gymnastics, men')]
for df, color, label in plots:
    df.plot.scatter(ax=ax, 
                    x= 'weight',
                    y= 'height',
                    alpha= .25,
                    color= color,
                    label= label)
    
ax.set_xlabel('weight (kg)')
ax.set_ylabel('height (m)')
ax.set_title('heights and weights of olymics athletes')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'heights and weights of olymics athletes')

# %%
fig, ax = plt.subplots()
gymnast_m.plot.scatter(ax= ax,
                       x= 'weight',
                       y= 'height',
                       c= 'gold',
                       colormap= 'plasma')
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### axes: ticks, ticks label, ranges, legends

# %%
styles= {'a': ':s', 'b': '--v', 'c': '-.o'}

with plt.style.context('ggplot'):
    fig, ax = plt.subplots(figsize= (6,3))
    for col in styles:
        grp[col].dropna().plot(ax= ax, style= styles)
        
fig.suptitle('Sales 2017', fontweight= 'bold')
ax.set_title('monthly sales for products a, b and c',
             fontstyle= 'italic',
             fontsize= '10')
ax.set_ylabel('Sales (EUR)')
ax.grid(True)

#x-axis customization

ax.set_xticks(range(1,13))

import calendar

ax.set_xticklabels([calendar.month_name[x] for x in grp.index],
                  rotation= 45,
                  ha= 'right')


fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
styles= {'a': ':s', 'b': '--v', 'c': '-.o'}

with plt.style.context('ggplot'):
    fig, ax = plt.subplots(figsize= (6,3))
    for col in styles:
        grp[col].dropna().plot(ax= ax, style= styles,
                               ylim= (0,20000), legend= True,
                               label= 'Product' + col)
        
fig.suptitle('Sales 2017', fontweight= 'bold')
ax.set_title('monthly sales for products a, b and c',
             fontstyle= 'italic',
             fontsize= '10')
ax.set_ylabel('Sales (EUR)')
ax.grid(True)

#x-axis customization

ax.set_xticks(range(1,13))

import calendar

ax.set_xticklabels([calendar.month_name[x] for x in grp.index],
                  rotation= 45,
                  ha= 'right')

#y-axis customization

def make_yticklabel(tick_value, pos):
    return "{}K".format(tick_value/1000)

from matplotlib.ticker import FuncFormatter
ax.yaxis.set_major_formatter(FuncFormatter(make_yticklabel))

#legend customization

ax.legend(labels= ['Apple', 'Pears', 'Oranges'],
          loc= 'upper left',
          markerfirst= False)

fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="766">
